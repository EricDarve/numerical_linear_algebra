# %%
# Click Cell -> Run All to see the animation

# File with movie to display
file_name = "QR.mp4"

# Display the animation
using Base64
display("text/html", string("""<video autoplay controls><source src="data:video/x-m4v;base64,""",
        base64encode(open(read,file_name)),"""" type="video/mp4"></video>"""));
# Out:
# <video autoplay controls><source src="data:video/x-m4v;base64,..." type="video/mp4"></video>
