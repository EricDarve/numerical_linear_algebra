# %%
try
    using PlotlyJS
catch
    # Package is probably not installed
    using Pkg
    Pkg.add("PlotlyJS")
    using PlotlyJS
end
# Out:
# HTML{String}("    <script class='js-collapse-script'>\n        var curMatch =\n            window.location.href\n            .match(/(.*?)\\/notebooks\\/.*\\.ipynb/);\n\n        curMatch = curMatch ||\n            window.location.href\n            .match(/(.*?)\\/apps\\/.*\\.ipynb/);\n\n        if ( curMatch ) {\n            \$('head').append('<base href=\"' + curMatch[1] + '/\">');\n        }\n    </script>\n")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/f562d6507acc94a42cdf3b074249b311a179837e-assets/webio/dist/bundle.js'></script>")
# HTML{String}("<script class='js-collapse-script' src='/assetserver/f562d6507acc94a42cdf3b074249b311a179837e-assets/providers/ijulia_setup.js'></script>")
# HTML{String}("  <script class='js-collapse-script'>\n    \$('.js-collapse-script').parent('.output_subarea').css('padding', '0');\n  </script>\n")

# %%
# Flag to generate PDF outputs
output = true
if output
    # The package ORCA needs to be installed for this to work
    using ORCA
end

# %%
# Set default values for all plots
nlaStyle = let
    colors = Cycler([
            "#E24A33", "#348ABD", "#988ED5", "#777777", 
            "#FBC15E", "#8EBA42", "#FFB5B8"
    ])
    nlaAxis = attr(showgrid=true, gridcolor="#E5E5E5", 
            linewidth=1.0,
            titlefont_color="#555555", titlefont_size=18,
            linecolor="black", mirror=true, zeroline=false,
            ticks="inside")
    nlaLayout = Layout(font_size=16, xaxis=nlaAxis, yaxis=nlaAxis,
        titlefont_size=18, width=500, height=300,
        margin=attr(l=50,b=50,r=50,t=60)
        )    
    gta = attr(
        marker_line_width=0.5, marker_line_color="#348ABD",
        marker_color=colors, marker_size=10
    )
    Style(layout=nlaLayout, global_trace=gta)
end

use_style!(nlaStyle)
# Out:
# Style with:
#   - layout with fields font, height, margin, titlefont, width, xaxis, and yaxis
#   - global_trace: PlotlyAttribute with field marker

# %%
x = LinRange(0,2pi,128)
p = plot(x,sin.(x))
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot1.pdf")
end

# %%
x = LinRange(0,2*pi,32)
X = [x x x]
Y = [cos.(x) cos.(x .+ pi/4) cos.(x .+ pi/2)]
p = plot(X,Y,mode="markers")
# Out:
# data: [
#   "scatter with fields marker, mode, type, x, and y",
#   "scatter with fields marker, mode, type, x, and y",
#   "scatter with fields marker, mode, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot2.pdf")
end

# %%
plot(cos,0,3*pi)
# Out:
# data: [
#   "scatter with fields marker, name, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot3.pdf")
end

# %%
p = plot([cos, sin, x -> cos(x/2)],0,3*pi,Layout(showlegend=false))
# Out:
# data: [
#   "scatter with fields marker, name, type, x, and y",
#   "scatter with fields marker, name, type, x, and y",
#   "scatter with fields marker, name, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, showlegend, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot3_1.pdf")
end

# %%
x1 = LinRange(0,2*pi,16)
t1 = scatter(x=x1,y=cos.(x1),
    mode="markers", marker_symbol="square-open", name="cos")
x2 = LinRange(0,2*pi,128)
t2 = scatter(x=x2,y=sin.(x2),
    line_dash="dash",
    name="sin")
p = plot([t1,t2])
# Out:
# data: [
#   "scatter with fields marker, mode, name, type, x, and y",
#   "scatter with fields line, marker, name, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot4.pdf")
end

# %%
x = LinRange(0,2*pi,128)
p = plot(x,cos.(x),
    Layout(title="A plot with too much empty space",
        xaxis_title="x coordinate",
        xaxis_range=[-1, 7],
        yaxis_title="y coordinate",
        yaxis_range=[-2, 2], margin_b = 150, height=350))
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, title, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot5.pdf")
end

# %%
x = LinRange(1,10,128)
p = plot(x,exp.(-3x),Layout(yaxis_type="log", margin_b = 50, height=300))
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot6.pdf")
end

# %%
x = LinRange(0.1,10,128)
p = plot(x,exp.(-x.^2),Layout(xaxis_domain=[0.05,1],
        yaxis_type="log", yaxis_exponentformat="SI"))
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot7.pdf")
end

# %%
θ = LinRange(0,2*pi,128)
p = plot(cos.(θ),sin.(θ),Layout(yaxis_scaleanchor="x",yaxis_scaleratio=1))
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot8.pdf")
end

# %%
x = LinRange(0,2π,64)
t1 = scatter(x=x,y=cos.(x),line_width=4, 
             line_color="rgb(0, 102, 204)",
             name="Thick line")
t2 = scatter(x=x,y=sin.(x),line_dash="dashdot", 
             line_color="BlueViolet",
             name="Dash dot line")
t3 = scatter(x=x,y=cos.(x).^2 .- 1/2, mode="markers",
    marker_symbol="circle-open", marker_size="10", 
    marker_color="LightSteelBlue",
    name="Markers")
l = Layout(font_size = 16, 
           title="Various line and marker styles", 
           titlefont_size="24", 
           titlefont_family="Marker Felt",
           showlegend=true)
p = plot([t1, t2, t3],l)
# Out:
# data: [
#   "scatter with fields line, marker, name, type, x, and y",
#   "scatter with fields line, marker, name, type, x, and y",
#   "scatter with fields marker, mode, name, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, showlegend, title, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot8_1.pdf")
end

# %%
x = LinRange(0,2π,64)
t = scatter(x=x,y=cos.(x))
l = Layout(xaxis_title="variable x", 
    xaxis_range=[-0.2, 6.4], 
    xaxis_tickvals=0:.4:6, xaxis_tickfont_size=16,
    xaxis_titlefont_size=18,
    yaxis_title="cos(x)", 
    yaxis_tickvals=-1.2:.3:1.2, yaxis_tickfont_size=12,
    yaxis_titlefont_size=18,
    width=400, height=250, margin_b=80, margin_l=60)
p = plot(t,l)
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot8_2.pdf")
end

# %%
x = LinRange(0,5,32)
t = scatter(x=x,y=x.^2)
l = Layout(xaxis_showgrid=true, xaxis_tickvals=1:1:4,
    xaxis_gridcolor="#DA70D6", xaxis_gridwidth=2,
    yaxis_showgrid=false, 
    yaxis_zeroline=true, yaxis_zerolinewidth=2, 
    yaxis_zerolinecolor="#C71585",
    yaxis_title="x^2",
    width=500, height=300, margin_b=50, margin_l=50)
p = plot(t,l)
# Out:
# data: [
#   "scatter with fields marker, type, x, and y"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot8_3.pdf")
end

# %%
n = 128
r = LinRange(1e-4,10,n)
t = LinRange(0,2π,n)
x = r * cos.(t)'
y = r * sin.(t)'
z = (x.^2 .* y.^2) ./ (x.^4 + y.^4)
p = plot(surface(x=x,y=y,z=z),Layout(width=700,height=500))
# Out:
# data: [
#   "surface with fields marker, type, x, y, and z"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
n = 129
u = LinRange(-2,2,n)
x = repeat(u,1,n); y = repeat(u',n,1)
z = cos.(x) .* sin.(y) ./ (x.^2 + y.^2 .+ 1)
p = plot(contour(x=u,y=u,z=z),Layout(width=500, height=300))
# Out:
# data: [
#   "contour with fields marker, type, x, y, and z"
# ]
#
# layout: "layout with fields font, height, margin, titlefont, width, xaxis, and yaxis"

# %%
if output
    savefig(p,"plot10.pdf")
end

# %%
t = LinRange(0,2π,128)
fx(r,t) = r .* cos.(t)
fy(r,t) = r .* sin.(t)
p1 = plot(fx(1,t),fy(1,t),name="1",Layout(yaxis_scaleanchor="x",yaxis_scaleratio=1))
p2 = plot(fx(t,t),fy(t,t),name="t",Layout(yaxis_scaleanchor="x2",yaxis_scaleratio=1))
r = cos.(3*t)
p3 = plot(fx(r,t),fy(r,t),name="cos(3t)",Layout(yaxis_scaleanchor="x3",yaxis_scaleratio=1))
r = cos.(t) + sin.(4*t)
p4 = plot(fx(r,t),fy(r,t),name="cos(t)+sin(4*t)",Layout(yaxis_scaleanchor="x4",yaxis_scaleratio=1))
p = [p1 p2; p3 p4]
relayout!(p,width=500, height=400, showlegend=false)
p
# Out:
# data: [
#   "scatter with fields marker, name, type, x, xaxis, y, and yaxis",
#   "scatter with fields marker, name, type, x, xaxis, y, and yaxis",
#   "scatter with fields marker, name, type, x, xaxis, y, and yaxis",
#   "scatter with fields marker, name, type, x, xaxis, y, and yaxis"
# ]
#
# layout: "layout with fields font, height, margin, showlegend, titlefont, width, xaxis1, xaxis2, xaxis3, xaxis4, yaxis1, yaxis2, yaxis3, and yaxis4"

# %%
if output
    savefig(p,"plot11.pdf")
end

# %%
try
    using JSON
catch
    # Installing package
    using Pkg
    Pkg.add("JSON")
    using JSON    
end

# %%
x = LinRange(0,2π,8)
pl = Plot(x,cos.(x))
println(JSON.json(pl,2))
# Out:
# {
#   "layout": {
#     "xaxis": {
#       "showgrid": true,
#       "gridcolor": "#E5E5E5",
#       "titlefont": {
#         "color": "#555555",
#         "size": 18
#       },
#       "zeroline": false,
#       "ticks": "inside",
#       "linewidth": 1.0,
#       "mirror": true,
#       "linecolor": "black"
#     },
#     "titlefont": {
#       "size": 18
#     },
#     "font": {
#       "size": 16
#     },
#     "height": 300,
#     "margin": {
#       "l": 50,
#       "b": 50,
#       "r": 50,
#       "t": 60
#     },
#     "yaxis": {
#       "showgrid": true,
#       "gridcolor": "#E5E5E5",
#       "titlefont": {
#         "color": "#555555",
#         "size": 18
#       },
#       "zeroline": false,
#       "ticks": "inside",
#       "linewidth": 1.0,
#       "mirror": true,
#       "linecolor": "black"
#     },
#     "width": 500
#   },
#   "data": [
#     {
#       "marker": {
#         "color": "#E24A33",
#         "line": {
#           "color": "#348ABD",
#           "width": 0.5
#         },
#         "size": 10
#       },
#       "y": [
#         1.0,
#         0.6234898018587336,
#         -0.22252093395631434,
#         -0.900968867902419,
#         -0.9009688679024191,
#         -0.2225209339563146,
#         0.6234898018587334,
#         1.0
#       ],
#       "type": "scatter",
#       "x": [
#         0.0,
#         0.8975979010256552,
#         1.7951958020513104,
#         2.6927937030769655,
#         3.5903916041026207,
#         4.487989505128276,
#         5.385587406153931,
#         6.283185307179586
#       ]
#     }
#   ]
# }

# %%
try
    using SpecialFunctions
catch
    # Installing package
    using Pkg
    Pkg.add("SpecialFunctions")
    using SpecialFunctions    
end

# %%
x = LinRange(-5,5,129)
t0 = scatter(y=airyai.(x))
t1 = scatter(y=airyaiprime.(x),xaxis="x2",yaxis="y2")
t2 = scatter(y=besselj0.(x),xaxis="x3",yaxis="y3")
layout = Layout(margin=attr(l=50,b=50,r=50,t=60))
println(JSON.json(layout,2))
# Out:
# {
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }

# %%
layout[:xaxis]  = attr(domain=[0, 0.45])
layout[:yaxis]  = attr(domain=[0.55, 1])
layout[:xaxis2] = attr(domain=[0.55, 1],anchor="y2")
layout[:yaxis2] = attr(domain=[0.55, 1],anchor="x2")
layout[:xaxis3] = attr(domain=[0, 1],anchor="y3")
layout[:yaxis3] = attr(domain=[0, 0.45],anchor="x3")
layout[:width] = 600; layout[:height] = 500
layout[:showlegend] = false
println(JSON.json(layout,2))
# Out:
# {
#   "showlegend": false,
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "xaxis2": {
#     "domain": [
#       0.55,
#       1.0
#     ],
#     "anchor": "y2"
#   },
#   "yaxis3": {
#     "domain": [
#       0.0,
#       0.45
#     ],
#     "anchor": "x3"
#   },
#   "height": 500,
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   },
#   "yaxis": {
#     "domain": [
#       0.55,
#       1.0
#     ]
#   },
#   "yaxis2": {
#     "domain": [
#       0.55,
#       1.0
#     ],
#     "anchor": "x2"
#   },
#   "xaxis3": {
#     "domain": [
#       0,
#       1
#     ],
#     "anchor": "y3"
#   },
#   "width": 600
# }

# %%
p = plot([t0, t1, t2],layout)
# Out:
# data: [
#   "scatter with fields marker, type, and y",
#   "scatter with fields marker, type, xaxis, y, and yaxis",
#   "scatter with fields marker, type, xaxis, y, and yaxis"
# ]
#
# layout: "layout with fields font, height, margin, showlegend, titlefont, width, xaxis, xaxis2, xaxis3, yaxis, yaxis2, and yaxis3"

# %%
if output
    savefig(p,"plot12.pdf")
end

# %%
layout = Layout()
layout[:xaxis] = attr(domain=[0, 0.45])
println(JSON.json(layout,2))
layout = Layout()
layout["xaxis"] = attr(domain=[0, 0.45])
println(JSON.json(layout,2))
layout = Layout()
layout[:xaxis_domain] = [0, 0.45]
println(JSON.json(layout,2))
layout = Layout()
layout["xaxis_domain"] = [0, 0.45]
println(JSON.json(layout,2))
layout = Layout()
layout["xaxis.domain"] = [0, 0.45]
println(JSON.json(layout,2))
layout = Layout()
layout["xaxis.domain"] = [0, 0.45]
println(JSON.json(layout,2))
# Out:
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
#
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
#
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
#
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
#
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
#
# {
#   "xaxis": {
#     "domain": [
#       0.0,
#       0.45
#     ]
#   },
#   "margin": {
#     "l": 50,
#     "b": 50,
#     "r": 50,
#     "t": 60
#   }
# }
